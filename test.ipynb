# %%
# import os
# from dotenv import load_dotenv
# from langchain_google_genai import ChatGoogleGenerativeAI
# from langchain_core.rate_limiters import InMemoryRateLimiter 
# load_dotenv()

# # Get API key from .env
# api_key = os.getenv("GOOGLE_API_KEY")

# if not api_key:
#     raise ValueError("GOOGLE_API_KEY not found. Make sure it's set in the .env file.")

# # Initialize a rate limiter for 10 requests per minute
# # This is the crucial addition tso manage your API calls
# rate_limiter = InMemoryRateLimiter(requests_per_second=10 / 60)

# # Define the LLM with the rate limiter included
# llm_model = ChatGoogleGenerativeAI(
#     model="gemini-2.5-flash",
#     google_api_key=api_key,
#     temperature=0,
#     max_retries=3,
#     rate_limiter=rate_limiter,
# )

# %%
import os
import logging
from dotenv import load_dotenv

from langchain_xai import ChatXAI

# ---------------- Logging ----------------
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)
logger = logging.getLogger(__name__)

# ---------------- Env ----------------
load_dotenv()

XAI_API_KEY = os.getenv("XAI_API_KEY")

if not XAI_API_KEY:
    logger.critical("XAI_API_KEY environment variable not set.")
    raise ValueError("API Key for Grok must be set.")

# ---------------- Grok LLM ----------------
llm_model = ChatXAI(
    api_key=XAI_API_KEY,
    model="grok-4-fast-reasoning",          
    temperature=0,
    max_retries=3,
    timeout=120,           
)

# %%
from langchain.chat_models import init_chat_model
from langchain_tavily import TavilySearch
from langgraph.checkpoint.memory import MemorySaver
from langchain.agents import create_agent

# Create the agent

model = llm_model
search = TavilySearch(max_results=2)
tools = [search]
agent_executor = create_agent(model, tools)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain.agents import create_agent

system_message = ("""You are a web search agent."""
)

agent_executor = create_agent(
    model=llm_model,
    tools=[search],
)

task_input = (
    "Find the latest news about how solo entrepreneur use AI to become multimillionaires. "
)

response = agent_executor.invoke({"messages": [("user", task_input)]})

print(response["messages"][-1].content)
# Out:
# 2026-03-03 10:36:37,213 - INFO - HTTP Request: POST https://api.x.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-03 10:36:43,952 - INFO - HTTP Request: POST https://api.x.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-03 10:36:49,271 - INFO - HTTP Request: POST https://api.x.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-03 10:36:54,411 - INFO - HTTP Request: POST https://api.x.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-03 10:37:17,668 - INFO - HTTP Request: POST https://api.x.ai/v1/chat/completions "HTTP/1.1 200 OK"
# ### Latest News on Solo Entrepreneurs Using AI to Become Multimillionaires
#
# While there aren't many headline-grabbing stories of purely solo entrepreneurs (solopreneurs) hitting multimillionaire status *exclusively* through AI in the past few months (as of October 2024), the trend is exploding in 2024. AI tools are democratizing business building, allowing individuals or tiny teams to create scalable products, automate operations, and achieve rapid growth without venture capital, large teams, or coding expertise. This is leading to more solopreneurs reaching seven-figure revenues or valuations. Below, I'll summarize key recent news and examples from reputable sources, focusing on 2024 developments. These highlight how AI enables bootstrapped success, often turning solo founders into millionaires via no-code platforms, automation, and generative AI.
#
# #### 1. **AI Boosts Solopreneur Productivity by 40%, Enabling Bootstrapped Million-Dollar Startups (Forbes, May 7, 2024)**
#    - **Key Insight**: A Forbes analysis shows AI can increase solopreneur output by up to 40%, allowing individuals to build and launch profitable tech businesses in days or weeks. This shift challenges traditional VC-funded models, focusing instead on "purpose, profitability, and progress."
#    - **How AI Helps**: Tools like no-code platforms (e.g., Bubble, Adalo) combined with AI (e.g., ChatGPT for coding assistance, automation via Zapier) let non-technical founders create software without developers.
#    - **Success Stories**:
#      - **Tal Flanchaych, Founder of ApplyAll**: A solo entrepreneur with no programming background used AI and no-code tools to build an automated job application platform in just days. It addresses market needs for efficient job hunting and has scaled to profitability, positioning Flanchaych for multimillion-dollar potential as user adoption grows.
#      - **Zach Sekar, Co-Founder of The Fulcrum**: While not purely solo, Sekar bootstrapped an AI accelerator community using AI for operations. He credits AI for making VC "obsolete," enabling solopreneurs to hit huge impacts without funding or teams. The Fulcrum helps others replicate this, with members launching AI-powered ventures reaching $1M+ ARR (annual recurring revenue).
#    - **Broader Trend**: The article notes several unnamed solopreneur startups hitting multimillion-dollar scales in 2024 by leveraging AI for product development and marketing, often without any employees.
#    - **Source**: [Forbes - AI Can Boost Solopreneur's Productivity By 40%](https://www.forbes.com/sites/jiawertz/2024/05/07/ai-can-boost-solopreneurs-productivity-by-40/)
#
# #### 2. **2024: The Best Time to Be a Solopreneur, Powered by AI (Forbes, June 4, 2024)**
#    - **Key Insight**: OpenAI CEO Sam Altman predicted in early 2024 that we'll see billion-dollar "unicorns" with fewer than 10 employees—many solo or near-solo. AI is the catalyst, reducing the need for co-founders, hires, or massive funding.
#    - **How AI Helps**: Generative AI handles tasks like content creation, customer service (via chatbots), and even product ideation. Combined with freelancers via platforms like Upwork, solopreneurs can scale globally.
#    - **Success Angle**: The piece emphasizes profitability over hype. Solopreneurs are using AI to foster "belonging and inclusion" in virtual operations, leading to sustainable growth. Examples include AI-driven online courses and SaaS tools that generate passive income, with some hitting multimillion-dollar exits or revenues in under a year.
#    - **Quote from Expert**: Zach Sekar (again) says, "We don’t need outside funds or expensive teams to make a huge impact." This mindset has led to solo AI ventures in e-learning and automation crossing $1M thresholds in 2024.
#    - **Source**: [Forbes - Why Now Is The Best Time To Be A Solopreneur](https://www.forbes.com/sites/aytekintank/2024/06/04/why-now-is-the-best-time-to-be-a-solopreneur/)
#
# #### 3. **Rapid AI Startup Funding Signals Solo-Friendly Boom (Business Insider, September 20, 2024)**
#    - **Key Insight**: The "funding velocity" for top AI startups is at an all-time high, with some raising multiple rounds in months. While not all are solo, this environment favors bootstrapped founders who use AI to prototype and validate ideas quickly, attracting investors and leading to multimillionaire outcomes.
#    - **How AI Helps**: Founders leverage AI for rapid iteration—e.g., generating code, designs, or market research—allowing solo operators to compete with big teams.
#    - **Relevant Example**:
#      - **Sakana AI (Founded 2023, Major 2024 Funding)**: Started by a small team of ex-Google engineers (near-solo origins), it raised $100M in Series A in September 2024 from Khosla Ventures and others. The founders used AI research tools to build evolutionary models, scaling to a valuation that made early backers (and founders) multimillionaires. This story inspires solo AI tinkerers aiming for similar exits.
#      - A stealth vertical software startup (unnamed, founded by a solo female entrepreneur) secured seed funding after 76 meetings, using generative AI to build its core product in months—highlighting how AI shortens the path to millionaire status.
#    - **Trend Note**: Investor Steve Brotman notes this rapid funding is creating more "overnight" multimillionaires among AI-savvy solos who start lean.
#    - **Source**: [Business Insider - The Hottest AI Startups Are Raising Back-to-Back Funding Rounds Again](https://www.businessinsider.com/ai-startups-rapid-funding-rounds-2024-9)
#
# #### 4. **Emerging Trends and Predictions for Late 2024**
#    - **Scaling AI Challenges and Wins (Forbes Video Series, September 16, 2024)**: A new Forbes series explores how solo entrepreneurs and small leaders use AI to solve industry problems. Early episodes feature bootstrapped AI tools for e-commerce and content, with founders reporting 5-10x revenue growth. One unnamed solopreneur scaled a personalized AI coaching app to $2M ARR solo.
#    - **Overall 2024 Context**: Reports from Rothschild & Co (June 2024) show Europe alone saw $2.3B in AI VC deals by May, with 5 of 14 new unicorns being AI-focused (e.g., Mistral AI, founded by two ex-DeepMind researchers who started small). Many began as solo projects, using open-source AI to bootstrap before exploding.
#    - **Challenges for Solos**: Per Fortune (January 2024, updated context), solo GPs (general partners) in AI investing face hurdles like market volatility, but successes like Recraft AI ($12M raise) show solos can thrive by focusing on niche tools.
#
# #### Why This Matters for Aspiring Solopreneurs
# AI lowers barriers: Tools like GPT-4, Midjourney, and no-code builders let anyone validate ideas fast and monetize via subscriptions or freelancing. Common paths to millions include:
# - **Building SaaS Tools**: AI-powered apps for automation (e.g., job tools, content generators).
# - **Content & E-Commerce**: Solo creators using AI for viral marketing, hitting $1M+ via platforms like Gumroad.
# - **Bootstrapping to Exit**: Start solo, use AI for MVP, then sell for millions.
#
# For the absolute latest, check ongoing series like Forbes' "Scaling AI." If you want details on specific tools or more examples, let me know! Sources are from trusted outlets like Forbes, Business Insider, and CNBC, based on searches up to October 2024.

# %%
from gtts import gTTS

def clean_text(x):
    if isinstance(x, list):
        return " ".join(str(i) for i in x)
    return str(x)

def generate_tts_audio(text, filename="output_audio.mp3"):
    text = clean_text(text)

    tts = gTTS(text=text, lang='en')
    tts.save(filename)

    print(f"Audio saved as {filename}")
    return filename

# %%
raw_output = response["messages"][-1].content
text = clean_text(raw_output)
generate_tts_audio(text, "industry_ears_news.mp3")
# Out:
# Audio saved as industry_ears_news.mp3
# 'industry_ears_news.mp3'

# %%
import os
print("ELEVENLABS_API_KEY:", os.getenv("ELEVENLABS_API_KEY"))
# Out:
# ELEVENLABS_API_KEY: sk_0e5a27603d28d11bd83e1b01558d344cff0fcca91fa75882

# %%
from elevenlabs.client import ElevenLabs
from elevenlabs.play import play

client = ElevenLabs(
    api_key="sk_0e5a27603d28d11bd83e1b01558d344cff0fcca91fa75882"
)

audio = client.text_to_speech.convert(
    text="The first move is what sets everything in motion.",
    voice_id="JBFqnCBsd6RMkjVDRZzb",
    model_id="eleven_multilingual_v2",
    output_format="mp3_44100_128",
)

play(audio)

# %%
from elevenlabs import ElevenLabs

client = ElevenLabs(api_key="sk_0e5a27603d28d11bd83e1b01558d344cff0fcca91fa75882")

audio_stream = client.text_to_speech.convert(
    text=text,
    voice_id="JBFqnCBsd6RMkjVDRZzb",
    model_id="eleven_multilingual_v2",
    output_format="mp3_44100_128",
)

with open("industry_ears_news.mp3", "wb") as f:
    for chunk in audio_stream:
        f.write(chunk)

print("✅ Audio saved")
# Out:
# ✅ Audio saved
